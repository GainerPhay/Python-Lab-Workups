# %%
import schemdraw
import schemdraw.elements as elm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
d = schemdraw.Drawing()
d += elm.Resistor().label('$R_S$')
d += elm.Dot()
d += elm.Line().up().length(d.unit*.5)
d += elm.Capacitor().right().label('$C_{DL}$')
d += elm.Line().down().length(d.unit*.5)
d += elm.Dot()
d.push()
d += elm.Line().right().length(d.unit*.5)
d.pop()
d += elm.Line().down().length(d.unit*.5)
d += elm.Resistor().left().label('$R_{CT}$',loc='bottom')
d += elm.Line().up().length(d.unit*.5)
d.save('randles.svg')
d

e = schemdraw.Drawing()
e += elm.Resistor().label('$R_S$')
e += elm.Dot()
e += elm.Line().up().length(d.unit*.5)
e += elm.Capacitor().right().label('$C_{DL_{anode}}$')
e += elm.Line().down().length(d.unit*.5)
e += elm.Dot()
e.push()
e += elm.Line().right().length(d.unit*.5)
e += elm.Line().up().length(d.unit*.5)
e += elm.Capacitor().right().label('$C_{DL_{cathode}}$')
e += elm.Line().down().length(d.unit*.5)
e += elm.Dot()
e.push()
e += elm.Line().right().length(d.unit*.5)
e.pop()
e += elm.Line().down().length(d.unit*.5)
e += elm.Resistor().left().label('$R_{CT_{cathode}}$',loc='bottom')
e += elm.Line().up().length(d.unit*.5)
e.pop()
e += elm.Line().down().length(d.unit*.5)
e += elm.Resistor().left().label('$R_{CT_{anode}}$',loc='bottom')
e += elm.Line().up().length(d.unit*.5)
e.save('two_randles.svg')

elm.style(elm.STYLE_IEEE)

e = schemdraw.Drawing()
#e += elm.Resistor().label('$R_u$')
#e += elm.Dot()
#e += elm.Line().up().length(d.unit*.5)
#e += elm.Capacitor().right().label('$C_{dl}$').length(d.unit*1)
#e += elm.Line().down().length(d.unit*.5)
#e += elm.Dot()
#e.push()
#e += elm.Line().right().length(d.unit*.5)
#e += elm.Line().up().length(d.unit*.5)
#e += elm.Capacitor().right().label('$C_{SEI}$')
#e += elm.Line().down().length(d.unit*.5)
#e += elm.Dot()
#e.push()
#e += elm.Line().right().length(d.unit*.5)
#e.pop()
#e += elm.Line().down().length(d.unit*.5)
#e += elm.Resistor().left().label('$R_{SEI}$',loc='bottom')
e += elm.Line().up().length(d.unit*.5)
e += elm.Line().down().length(d.unit*.5)
e += elm.ResistorIEC().left().label('$Z_{W}$',loc='bottom')
e += elm.Resistor().left().label('$R_{CT}$',loc='bottom')
e += elm.Line().up().length(d.unit*.5)
e += elm.Dot()
e.push()
e += elm.Resistor().label('$R_S$').left()
e.pop()
e += elm.Line().up().length(d.unit*.5)
e += elm.Line().right().length(d.unit*.5)
e += elm.Capacitor().right().label('$C_{DL}$')
e += elm.Line().right().length(d.unit*.5)
e += elm.Line().down().length(d.unit*.5)
e += elm.Dot()
e += elm.Line().right().length(d.unit*.5)
e.save('warburg_circuit.svg')

# %%
e = schemdraw.Drawing()
e += elm.Resistor().label('$R_S$')
e += elm.Dot()
e += elm.Line().up().length(d.unit*.5)
e += elm.Capacitor().right().label('$C_1$')
e += elm.Line().down().length(d.unit*.5)
e += elm.Dot()
e.push()
e += elm.Line().right().length(d.unit*.5)
e += elm.Line().up().length(d.unit*.5)
e += elm.Capacitor().right().label('$C_2$')
e += elm.Line().down().length(d.unit*.5)
e += elm.Dot()
e.push()
e += elm.Line().right().length(d.unit*.5)
e.pop()
e += elm.Line().down().length(d.unit*.5)
e += elm.Resistor().left().label('$R_2$',loc='bottom')
e += elm.Line().up().length(d.unit*.5)
e.pop()
e += elm.Line().down().length(d.unit*.5)
e += elm.Resistor().left().label('$R_1$',loc='bottom')
e += elm.Line().up().length(d.unit*.5)
e.save('two_randles_general.svg')
